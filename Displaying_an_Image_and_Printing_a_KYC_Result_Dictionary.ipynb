# %%
result = {
    "doc_type": "Aadhar",
    "document_validity_score": 0.94,
    "tampering_score": 0.12,
    "face_match_score": 0.88,
    "address_verified": True,
    "name_similarity": 0.91,
    "overall_kyc_status": "APPROVED"
}

print(result)
# Out:
# {'doc_type': 'Aadhar', 'document_validity_score': 0.94, 'tampering_score': 0.12, 'face_match_score': 0.88, 'address_verified': True, 'name_similarity': 0.91, 'overall_kyc_status': 'APPROVED'}

# %% [markdown]
# # Task
# Display the image from '/6.jpg' and print the 'result' dictionary.

# %% [markdown]
# ## Display image
#
# ### Subtask:
# Display the image from the file '/6.jpg'.

# %% [markdown]
# **Reasoning**:
# To display the image, I need to import the Image class from IPython.display, create an Image object with the provided file path, and then display it.

# %%
from IPython.display import Image, display

# Create an Image object with the file path
image_path = '/6.jpg'
image = Image(filename=image_path)

# Display the image
display(image)

# %% [markdown]
# **Reasoning**:
# The image has been displayed. Now, I need to print the 'result' dictionary as per the main task's instructions.

# %%
print(result)
# Out:
# {'doc_type': 'Aadhar', 'document_validity_score': 0.94, 'tampering_score': 0.12, 'face_match_score': 0.88, 'address_verified': True, 'name_similarity': 0.91, 'overall_kyc_status': 'APPROVED'}
